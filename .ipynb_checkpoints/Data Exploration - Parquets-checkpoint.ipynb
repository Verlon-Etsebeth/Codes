# %%
import pyarrow.parquet as pq
import numpy as np

# %% [markdown]
# ## TSNE_Plot

# %%
TSNE_Plot = pq.read_table('/home/verlon/Desktop/Astronomaly/Data/Output/Coadd026/0260m062_500_test/TSNE_Plot_output.parquet').to_pandas()

# %%
TSNE_Plot
# Out:
#               0         1
# 6542 -10.917696 -2.271037
# 6701 -11.731854 -5.724232
# 4638 -11.708801 -5.697583
# 793  -10.245337 -1.616458
# 4646 -11.460214 -4.621159
# ...         ...       ...
# 8173   3.967238 -3.431386
# 4733   4.753619 -3.290356
# 3836  -1.157628  1.439006
# 7095   5.028538 -2.018188
# 4356   1.202937 -4.709286
#
# [423 rows x 2 columns]

# %% [markdown]
# ## ScoreConverter

# %%
ScoreConverter = pq.read_table('/home/verlon/Desktop/Astronomaly/Data/Output/Coadd026/0260m062_500_test/ScoreConverter_output.parquet').to_pandas()

# %%
ScoreConverter
# Out:
#          score
# 594   0.909272
# 6095  1.028981
# 2709  0.948610
# 5667  1.310666
# 2471  0.699654
# ...        ...
# 6345  0.465632
# 4612  0.083223
# 2445  2.990038
# 3190  0.234589
# 8031  0.476918
#
# [423 rows x 1 columns]

# %% [markdown]
# ## IforestAlgorithm

# %%
IforestAlgorithm = pq.read_table('/home/verlon/Desktop/Astronomaly/Data/Output/Coadd026/0260m062_500_test/IforestAlgorithm_output.parquet').to_pandas()

# %%
IforestAlgorithm
# Out:
#          score
# 594   0.072175
# 6095  0.062151
# 2709  0.068881
# 5667  0.038563
# 2471  0.089728
# ...        ...
# 6345  0.109325
# 4612  0.141348
# 2445 -0.102066
# 3190  0.128672
# 8031  0.108380
#
# [423 rows x 1 columns]

# %% [markdown]
# ## EllipseFitFeatures

# %%
EllipseFitFeatures = pq.read_table('/home/verlon/Desktop/Astronomaly/Data/Output/Coadd026/0260m062_500_test/EllipseFitFeatures_output.parquet').to_pandas()

# %%
EllipseFitFeatures
# Out:
#       Residual_90  Residual_80  Residual_70  Residual_60  Residual_50  \
# 594      0.006836     0.007812     0.005859     0.007812     0.012695
# 6095     0.004883     0.006836     0.008789     0.009766     0.005859
# 2709     0.006836     0.010742     0.009766     0.017578     0.026367
# 5667     0.005859     0.009766     0.003906     0.009766     0.018555
# 2471     0.009766     0.008789     0.009766     0.020508     0.012695
# ...           ...          ...          ...          ...          ...
# 6345     0.034180     0.033203     0.033203     0.033203     0.033203
# 4612     0.029297     0.050781     0.050781     0.050781     0.050781
# 2445     0.004883     0.096680     0.111328     0.111328     0.111328
# 3190     0.031250     0.038086     0.038086     0.038086     0.038086
# 8031     0.040039     0.040039     0.040039     0.040039     0.040039
#
#       Residual_0  Offset_90  Offset_80  Offset_70  Offset_60  ...  Aspect_70  \
# ...

# %%
EllipseFitFeatures.dropna()
# Out:
#       Residual_90  Residual_80  Residual_70  Residual_60  Residual_50  \
# 594      0.006836     0.007812     0.005859     0.007812     0.012695
# 6095     0.004883     0.006836     0.008789     0.009766     0.005859
# 2709     0.006836     0.010742     0.009766     0.017578     0.026367
# 5667     0.005859     0.009766     0.003906     0.009766     0.018555
# 2471     0.009766     0.008789     0.009766     0.020508     0.012695
# ...           ...          ...          ...          ...          ...
# 6345     0.034180     0.033203     0.033203     0.033203     0.033203
# 4612     0.029297     0.050781     0.050781     0.050781     0.050781
# 2445     0.004883     0.096680     0.111328     0.111328     0.111328
# 3190     0.031250     0.038086     0.038086     0.038086     0.038086
# 8031     0.040039     0.040039     0.040039     0.040039     0.040039
#
#       Residual_0  Offset_90  Offset_80  Offset_70  Offset_60  ...  Aspect_70  \
# ...

# %% [markdown]
# ## Feature Scalar Output

# %%
FeatureScalar = pq.read_table('/home/verlon/Desktop/Astronomaly/Data/Output/Coadd026/0260m062_500_test/FeatureScaler_output.parquet').to_pandas()

# %%
FeatureScalar
# Out:
#       Residual_90  Residual_80  Residual_70  Residual_60  Residual_50  \
# 594     -0.660322    -1.639257    -1.779901    -1.784644    -1.698251
# 6095    -0.731904    -1.677982    -1.670701    -1.709603    -1.970697
# 2709    -0.660322    -1.523083    -1.634301    -1.409443    -1.153361
# 5667    -0.696113    -1.561808    -1.852701    -1.709603    -1.464727
# 2471    -0.552947    -1.600533    -1.634301    -1.296882    -1.698251
# ...           ...          ...          ...          ...          ...
# 6345     0.341837    -0.632413    -0.760700    -0.809121    -0.880916
# 4612     0.162880     0.064633    -0.105500    -0.133760    -0.180342
# 2445    -0.731904     1.884697     2.151301     2.192486     2.232745
# 3190     0.234463    -0.438789    -0.578700    -0.621521    -0.686312
# 8031     0.556586    -0.361340    -0.505900    -0.546481    -0.608470
#
#       Residual_0  Offset_90  Offset_80  Offset_70  Offset_60  ...  Aspect_70  \
# ...
